# %% [markdown]
# # Домашняя работа №1

# %%
import numpy as np
import pylab as pl
import pandas as pd
import warnings
import math

import matplotlib as mpl 
from mpl_toolkits.mplot3d import Axes3D

from matplotlib import pyplot as plt
from scipy import linalg


warnings.filterwarnings("ignore")

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Изобразите с помощью matplotlib. Изобразите точку x + 2y + 3z. Найдите угол между векторами x, y и x, z.

# %%
x = np.array([1,1])
y = np.array([2, 0])
z = np.array([0,2])

# %%
dot = np.array([(x[0]+2*y[0]+3*z[0]), (x[1]+2*y[1]+3*z[1])])
dot
# Out:
# array([5, 7])

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca(projection='3d')

ax.plot([0,x[0]], [0,x[1]])
ax.plot([0,y[0]*2], [0,y[1]*2])
ax.plot([0,z[0]*3], [0,z[1]*3])

ax.plot([0,dot[0]], [0,dot[1]])
ax.scatter(dot[0], dot[1])

ax.set_xlabel('Ось Х')
ax.set_ylabel('Ось Y')
ax.set_zlabel('Ось Z')

ax.legend(['x', 'y', 'z'])

plt.show()

# %%
"""
Считаем косинус
"""

def cosine(a, b): 
    aLength = np.linalg.norm(a)
    bLength = np.linalg.norm(b)
    return np.dot(a, b) / (aLength*bLength)

# %%
math.degrees(np.arccos(cosine(x, y)))
# Out:
# 45.00000000000001

# %%
math.degrees(np.arccos(cosine(x, z)))
# Out:
# 45.00000000000001

# %%
math.degrees(np.arccos(cosine(y, z)))
# Out:
# 90.0

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Загрузите модель человека. Найдите расстояние от правой кисти до позвоночника

# %%
ns = ['type', 'x', 'y', 'z']
dfJointsVertexes = pd.read_csv('joints.txt', sep=' ', names = ns)
axis_sort = 'x' 
df = dfJointsVertexes.sort_values(by=[axis_sort])

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca(projection='3d')

x = np.array(dfJointsVertexes.x)
y = np.array(dfJointsVertexes.y)
z = np.array(dfJointsVertexes.z)

ax.scatter(x, y, z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()

# %%
plt.scatter(df.x, df.y)

# %%
# вообще не понятно, как искать по номерам, делал методом простого подбора цифр :))))

plt.scatter(df.x, df.y)
plt.scatter(df.x[16], df.y[0])
plt.scatter(df.x[0], df.y[16])

plt.legend(['все параметрические точки', 'точка кисти', 'точка позвоночника'])

# %%
vect = [df.x[0]-df.x[16], df.y[0]-df.y[16], df.z[0]-df.z[16]]
np.linalg.norm(vect)
# Out:
# 0.3996718642286445

# %% [markdown]
# # Задание 3

# %% [markdown]
# Найдите собственные значения и собственные вектора матриц (необходимо решение на numpy). Для матрицы 3x3 можно посмотреть на корни характеристического многочлена, посчитанные в numpy.

# %%
m1 = np.array([[2, 2],
               [1, 3]])

m2 = np.array([[4, 1, -1],
               [1, 4, -1],
               [-1, -1, 4]])

# %%
e_vals, e_vecs = np.linalg.eig(m1)

# %%
e_vals
# Out:
# array([1., 4.])

# %%
e_vecs
# Out:
# array([[-0.89442719, -0.70710678],
#        [ 0.4472136 , -0.70710678]])

# %%
e_vals_2, e_vecs_2 = np.linalg.eig(m2)

# %%
e_vals_2
# Out:
# array([3., 6., 3.])

# %%
e_vecs_2
# Out:
# array([[-0.81649658,  0.57735027, -0.27658128],
#        [ 0.40824829,  0.57735027,  0.8035929 ],
#        [-0.40824829, -0.57735027,  0.52701162]])
